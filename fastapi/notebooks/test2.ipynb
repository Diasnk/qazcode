# %% [markdown]
# # LLM API — Getting Started
#
# This notebook shows how to call the **GPT-OSS** model hosted on `hub.qazcode.ai`.
#
# The server uses the **OpenAI-compatible API**, so you can use the `openai` Python library or plain `requests`.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
API_KEY = os.environ.get('API_KEY')
HUB_URL = os.environ.get('HUB_URL')

if not API_KEY:
    raise ValueError("API_KEY is not set in environment variables")

# %%
from openai import OpenAI

client = OpenAI(
    base_url=HUB_URL,
    api_key=API_KEY,  # replace with your key
)

MODEL = "oss-120b"

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "user", "content": "Hello! Who are you?"}
    ],
)

print(response.choices[0].message.content)
# Out:
# Hello! I’m ChatGPT, an AI language model created by OpenAI. I can help you with a wide range of tasks—answering questions, explaining concepts, brainstorming ideas, drafting or editing text, solving math problems, coding, learning new topics, planning trips, and much more.
#
# What are you curious about or working on today? Let me know how I can assist you!

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {
            "role": "system",
            "content": "You are a medical diagnosis assistant. Given patient symptoms, suggest the most probable diagnosis with an ICD-10 code."
        },
        {
            "role": "user",
            "content": "Patient presents with fever, dry cough, and shortness of breath lasting 5 days."
        }
    ],
)

print(response.choices[0].message.content)
# Out:
# **Most Probable Diagnosis:**
# **COVID‑19, virus identified** – *ICD‑10‑CM code: **U07.1***
#
# ---
#
# ### Rationale
# | Clinical Feature | Typical Association |
# |------------------|----------------------|
# | **Fever** (5 days) | Common in acute viral infections, especially SARS‑CoV‑2 |
# | **Dry (non‑productive) cough** | Characteristic of early COVID‑19; less typical for bacterial pneumonia |
# | **Shortness of breath** (dyspnea) | Frequently reported when the infection involves the lower respiratory tract |
# | **Duration ≈ 5 days** | Fits the usual incubation‑to‑symptom window of COVID‑19 (2‑14 days) and the acute phase of viral pneumonia |
#
# Given the current epidemiology (ongoing community transmission of SARS‑CoV‑2 in most regions) and the classic triad of fever, dry cough, and dyspnea, COVID‑19 is the leading diagnosis.
#
# ---
#
# ### Important Differentials (with ICD‑10 codes)
#
# | Condition | ICD‑10 | Why it’s considered |
# |-----------|--------|---------------------|
# | **Influenza, virus identified** | J10.1 (influenza due to identified influenza virus) | Fever, cough, and dyspnea can also be seen with flu, especially during seasonal peaks. |
# | **Viral pneumonia, unspecified** | J12.9 | General viral lower‑respiratory‑tract infection; would be used if COVID‑19 testing is negative and no specific virus identified. |
# | **Acute bronchitis, unspecified** | J20.9 | Dry cough and mild dyspnea, but fever is less prominent. |
# | **Bacterial pneumonia, not otherwise specified** | J15.9 | Dyspnea and fever, but cough is usually productive. |
# | **Pulmonary embolism** | I26.99 (other acute pulmonary embolism) | Sudden dyspnea, but typically lacks fever and dry cough. |
#
# ---
#
# ### Suggested Immediate Work‑up (to confirm the diagnosis)
#
# 1. **SARS‑CoV‑2 testing**
#    - RT‑PCR (nasopharyngeal swab) – gold standard.
#    - Rapid antigen test if PCR unavailable (confirm negative results with PCR in high‑pre‑test probability cases).
#
# 2. **Basic laboratory panel**
#    - CBC with differential (look for lymphopenia).
#    - CRP, ESR, ferritin, D‑dimer (risk stratification).
#    - Liver function tests, renal function, electrolytes.
#
# 3. **Chest imaging**
#    - **Chest X‑ray** (initial) – may show bilateral peripheral infiltrates.
#    - **Low‑dose CT chest** (if X‑ray equivocal or patient deteriorates) – typical “ground‑glass” opacities.
#
# 4. **Pulse oximetry / arterial blood gas**
#    - Document oxygen saturation; initiate supplemental O₂ if SpO₂ < 94 % on room air.
#
# 5. **Additional viral panel** (if SARS‑CoV‑2 negative)
#    - Influenza A/B PCR, RSV, other respiratory viruses as clinically indicated.
#
# ---
#
# ### Management Overview (if COVID‑19 is confirmed)
#
# | Severity | Key Interventions |
# |----------|-------------------|
# | **Mild (no hypoxia, outpatient)** | - Symptomatic care (antipyretics, adequate hydration).  <br> - Educate on isolation (≥10 days from symptom onset + 24 h afebrile). |
# | **Moderate (requiring supplemental O₂, SpO₂ 90‑94 %)** | - Oral antivirals (e.g., **Paxlovid** – nirmatrelvir/ritonavir, or **molnupiravir**) if within 5 days of symptom onset and no contraindications. <br> - Home monitoring of vitals + telehealth follow‑up. |
# | **Severe / Critical (hospitalized, SpO₂ < 90 % or respiratory failure)** | - Hospital admission, supplemental O₂/ high‑flow nasal cannula or mechanical ventilation as needed. <br> - **Dexamethasone 6 mg daily** (≤10 days) for patients on O₂. <br> - Consider **remdesivir**, **tocilizumab** or **baricitinib** per institutional protocols. <br> - Anticoagulation prophylaxis (unless contraindicated). |
#
# ---
#
# ### Disposition Recommendation
#
# - **If rapid antigen or PCR is positive** → treat/monitor as COVID‑19 according to severity.
# - **If test is negative but clinical suspicion remains high** → repeat PCR in 24‑48 h; consider chest CT and broader viral panel.
# - **If alternative diagnosis is established** → manage according to that condition (e.g., start oseltamivir for influenza).
#
# ---
#
# **Bottom line:** The presentation most strongly fits **COVID‑19 (U07.1)**; confirm with SARS‑CoV‑2 testing and proceed with appropriate isolation, monitoring, and treatment based on disease severity.

# %%
import requests

response = requests.post(
    f"{HUB_URL}/chat/completions",
    headers={
        "Content-Type": "application/json",
        "Authorization": f"Bearer {API_KEY}",
    },
    json={
        "model": "oss-120b",
        "messages": [{"role": "user", "content": "Hello!"}],
    },
)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# Hi there! How can I help you today?

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="oss-120b",
    api_key=API_KEY,
    base_url=HUB_URL,
    temperature=0
)

print(llm.invoke("Hello!").content)
# Out:
# Hello! 👋 How can I assist you today?

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
    model="ai-forever/ru-en-RoSBERTa",
    openai_api_base="http://localhost:8081/v1",
    openai_api_key="unused",
    check_embedding_ctx_length=False,
)

# %%
import shutil
from pathlib import Path
from langchain_chroma import Chroma

# Set to True to remove old DB (fixes "readonly database" or start fresh); set back to False after.
CLEAR_CHROMA_DB = True

persist_dir = (Path.cwd() / "chroma_langchain_db").resolve()
if CLEAR_CHROMA_DB and persist_dir.exists():
    shutil.rmtree(persist_dir)
    print("Removed existing chroma_langchain_db")

persist_dir.mkdir(parents=True, exist_ok=True)

vector_store = Chroma(
    collection_name="example_collection",
    embedding_function=embeddings,
    persist_directory=str(persist_dir),
)
# Out:
# Removed existing chroma_langchain_db

# %%
import json
from pathlib import Path
from langchain_core.documents import Document

data_dir = Path("../extracted_data")

docs = []
for json_file in sorted(data_dir.glob("*.json")):
    with open(json_file) as f:
        data = json.load(f)
    # identified_symptoms is a list; page_content must be a string for LangChain/embedders
    symptoms = data["identified_symptoms"]
    page_content = "\n".join(symptoms) if isinstance(symptoms, list) else str(symptoms)
    docs.append(Document(
        page_content=page_content,
        metadata={
            "gt": data["gt"],
        },
    ))

print(f"Loaded {len(docs)} documents")
docs[0]
print(f"Total characters: {len(docs[0].page_content)}")
# Out:
# Loaded 221 documents
# Total characters: 456

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # chunk size (characters)
    chunk_overlap=200,  # chunk overlap (characters)
    add_start_index=True,  # track index in original document
)
all_splits = text_splitter.split_documents(docs)

print(f"Split blog post into {len(all_splits)} sub-documents.")
# Out:
# Split blog post into 220 sub-documents.

# %%
BATCH_SIZE = 1000
document_ids = []
for i in range(0, len(all_splits), BATCH_SIZE):
    batch = all_splits[i : i + BATCH_SIZE]
    document_ids.extend(vector_store.add_documents(documents=batch))
    print(f"Added batch {i // BATCH_SIZE + 1} ({len(batch)} docs)")

print(f"\nTotal documents added: {len(document_ids)}")
# Out:
# Added batch 1 (220 docs)
#
# Total documents added: 220

# %%
print(vector_store._collection.count())
# Out:
# 220

# %%
# Top 20 candidates by similarity score (same idea as docs; feed these to the agent via retrieve_context)
query = "Когда идём, его качает, будто пол уплывает, пару раз чуть не упал."
results = vector_store.similarity_search_with_score(query, k=20)
for res, score in results:
    print(f"* [SIM={score:.3f}] {res.page_content[:300]}... [{res.metadata}]")
# Out:
# * [SIM=0.651] тянет низ живота, больше справа
# кольнёт, отдаёт в поясницу
# месечные задерживаются на 9 дней
# коричневатое мазание
# боль усиливается после ходьбы или близости
# живот будто надувается
# тошнота
# одноразовое скручивание живота (спасение) в течение ~10 минут... [{'start_index': 0, 'gt': 'N83.1'}]
# * [SIM=0.653] тошнота
# боль в животе
# головная боль
# слабость
# диарея
# боль в спине и мышцах... [{'gt': 'Z29.2', 'start_index': 0}]
# * [SIM=0.685] вздутие живота
# тяжесть внизу живота
# дискомфорт при ходьбе
# одежда давит в животе
# одышка, особенно в положении лёжа
# тошнота
# рвота
# очень малое количество мочи (олиурия)
# головокружение
# слабость... [{'gt': 'N98.9', 'start_index': 0}]
# * [SIM=0.687] острая боль в правом локте после травмы
# нежелание использовать руку, удерживание локтя в сгибе
# болезненность при попытке одеть футболку, повернуть кисть
# отёк небольшого размера, синяков почти нет
# отсутствие движения в локте, но пальцы шевелятся
# тепло в области локтя, боль усиливается при пальпации... [{'gt': 'S53.0', 'start_index': 0}]
# * [SIM=0.696] боль в правой руке и плече
# постоянное онемение, особенно мизинца и безымянного пальца
# жгучее ощущение, покалывание
# боль, усиливающаяся при поднятии руки вверх или вытягивании к полке
# радиальная боль от шеи через плечо к внутренней стороне предплечья
# холодная кисть с синеватым оттенком
# отёк кисти
# ощу... [{'gt': 'Q68.0', 'start_index': 0}]
# * [SIM=0.703] слабость
# усталость от небольших нагрузок
# тахикардия при физической активности
# одышка (недостаток дыхания)
# головокружение
# потемнение в глазах
# бледность кожи и губ
# нарушенный сон
# общая утомляемость... [{'gt': 'D46.0', 'start_index': 0}]
# * [SIM=0.705] тянет правая голень
# полоска покраснения по внутренней стороне ноги
# кожа горячая на ощупь
# ощущение плотного шнурка под пальцами, боль при контакте
# отёк ноги к вечеру
# тузже застёгиваются носок и кроссовок
# ощущение тяжести, как будто привязан гирей
# пульсирующая боль при ходьбе или стоянии, усиливается
# ... [{'start_index': 0, 'gt': 'I80.3'}]
# * [SIM=0.705] падение с отведенной рукой и удар плечом
# боль в области соединения ключицы с грудью (центр кости)
# ограничение поднятия руки вверх, боль при попытке надеть одежду или дотянуться до верхних полок
# ощущается отёк и болезненная шишка в зоне ключицы
# ощущение щёлкающего звука/перемещения при движении
# ночна... [{'start_index': 0, 'gt': 'S43.6'}]
# * [SIM=0.705] давление в груди, сильная боль по центру
# боль жжёт, отдаёт в левое плечо, челюсть, под левую лопатку
# затруднённое дыхание, тяжесть при вдохе
# холодный липкий пот
# головокружение
# тошнота, почти рвота
# боль длится более часа
# предыдущий кратковременный похожий эпизод
# учащённое сердцебиение (сердце колотит... [{'gt': 'I21.3', 'start_index': 0}]
# * [SIM=0.706] давит изнутри, особенно за глазами и в висках
# тошнота и рвота по утрам
# ухудшение зрения, боковое поле зрения ограничено, «картинка обрезана»
# быстрая усталость глаз, к вечеру зрение «плывёт»
# повышенная жажда, постоянное желание пить
# ночные частые позывы к мочеиспусканию
# колебания веса, отёк
# нарушения... [{'start_index': 0, 'gt': 'C75.2'}]
# * [SIM=0.714] падение на вытянутую руку
# ощущение щелчка в запястье/локтевом суставе
# деформация руки, искривление
# быстрое отёкание и распространение синяка
# пульсирующая сильная боль
# боль усиливается при движении руки
# хруст/скрип при попытке движения
# неспособность повернуть ладонь
# слабость кисти, невозможность удер... [{'start_index': 0, 'gt': 'S52.7'}]
# * [SIM=0.718] перелом коленного сустава год назад
# установка металлического импланта в колено
# боль в колене при ходьбе, особенно после 15‑20 минут нагрузки
# вечернее усиление боли, ощущение натяжения
# боль при попытке встать после сидения, первые шаги болезненны
# утренняя скованность колена, требуется полчаса для раз... [{'gt': 'Z87.3', 'start_index': 0}]
# * [SIM=0.718] установлен шунт при гидроцефалии (год назад)
# головная боль/ощущение тяжести в лобной области
# рвота натощак
# вялость, летаргия
# капризность, плач без очевидной причины
# фотофобия (свет режет глаза)
# расстройства зрения (косил глазиком, смотрит вниз через ресницы)
# нарушения походки, ощущение, что пол «упл... [{'gt': 'G91.1', 'start_index': 0}]
# * [SIM=0.720] падение с высоты
# резкая боль в бедре/нижней конечности
# неспособность встать на ногу
# отёк в области бедра
# сильный синяк над бедром
# ощущение удлинения/короткости ноги
# наружный (внешний) ротационный деформитет (ступня направлена наружу)
# болезненные движения, «шевеление»/«хруст» при попытке перемещения
# ... [{'gt': 'S72.9', 'start_index': 0}]
# * [SIM=0.723] диспноэ при нагрузке
# ортостатическая одышка (нужда спать полусидя)
# давление в груди, чувство нехватки воздуха
# плетиальное отёк ног (следы от носков, обувь не влезает)
# абдоминальная подпухлость/ощущение тяжести в животе
# усталость, слабость, быстрая утомляемость
# головокружение, почти падения
# весовые к... [{'start_index': 0, 'gt': 'I42.0'}]
# * [SIM=0.723] давление за грудиной при нагрузке
# боль уменьшается после отдыха (примерно 3 минуты)
# ухудшение боли на холоде
# облегчение боли при применении нитроглицерина
# одышка при физической нагрузке
# пальпации/учащенное сердцебиение
# ночные пробуждения из‑за нехватки воздуха
# слегка синеватые губы после подъёма по ... [{'gt': 'Q23.9', 'start_index': 0}]
# * [SIM=0.724] запоздалое сидение, ползание и контроль головы
# запоздалое самостоятельное хождение, делает несколько шагов, но шатается
# широкая постановка ног, нестабильная походка, частые падения
# страх ступенек, удерживается за перила или за сопровождающего
# тремор рук при попытке взять предметы (ложку, кубик)
# затр... [{'gt': 'G80.4', 'start_index': 0}]
# * [SIM=0.733] отёк лица (одутловатое, припухшие веки)
# отёк нижних конечностей (ноги налившиеся, обувь не налезает)
# быстрый набор веса (два килограмма за короткое время)
# уменьшение частоты мочеиспускания (реже мочится)
# пенистая (пенная) моча
# усталость, вялость
# ощущение тяжести/распирания в животе (абдоминальная оп... [{'gt': 'N04.3', 'start_index': 0}]
# * [SIM=0.734] провалы в настроение, ощущение пустоты
# раннее пробуждение (просыпаюсь на 2 часа раньше)
# ощущение тяжести в груди
# отсутствие желания заниматься обычными делами, анхедония
# быстрая утомляемость, чувство «выжатой» после короткой прогулки
# нарушения концентрации, мысли путаются, затруднённость в выполнени... [{'start_index': 0, 'gt': 'F32.1'}]
# * [SIM=0.737] перелом бедра ближе к колену
# длительное ношение гипса
# хромота при ходьбе
# ощущение натяжения бедра и колена как деревянного
# ограничение сгибания бедра/колена
# боль после упражнений
# ночная боль, пробуждение
# поиск опоры, страх наступать на пораженную ногу
# перенапряжение второй ноги, усталость спины
# небо... [{'gt': 'S72.8', 'start_index': 0}]

# %%
from pydantic import BaseModel, Field
from typing import Annotated

class AgentResponse(BaseModel):
    ICD_10_code: Annotated[
        list[str],
        Field(
            description="ICD-10 codes that identify diseases or conditions.",
            min_length=3,
            max_length=3
        )
    ]

# %%
from langchain.tools import tool

@tool
def get_top3_protocols(query: str) -> str:
    """Retrieve the top 3 most relevant clinical protocol excerpts for the given patient symptoms query. Call this first with the user's symptoms."""
    results = vector_store.similarity_search_with_score(query, k=3)
    parts = []
    for i, (doc, score) in enumerate(results, 1):
        parts.append(f"[Match {i}, score={score:.3f}] Source: {doc.metadata}\nContent: {doc.page_content}")
    return "\n\n---\n\n".join(parts)

from langchain.agents import create_agent

tools = [get_top3_protocols]
prompt = (
    "You are a medical diagnosis assistant. "
    "You MUST call get_top3_protocols first with the patient's symptoms (the user message) to retrieve the top 3 relevant clinical protocol excerpts. "
    "Based only on that retrieved context, respond with exactly 3 ICD-10 codes (most probable diagnoses, ranked by likelihood). "
    "Your final response must be a valid JSON object with this exact structure: {\"ICD_10_code\": [\"code1\", \"code2\", \"code3\"]}. "
    "Example: {\"ICD_10_code\": [\"R42\", \"G43.1\", \"F41.0\"]}. No other text, only the JSON."
)
agent = create_agent(llm, tools, system_prompt=prompt)

# %%
import json
import re
query = "Когда идём, его качает, будто пол уплывает, пару раз чуть не упал."
result = agent.invoke({"messages": [{"role": "user", "content": query}]})
last_message = result["messages"][-1]
content = last_message.content if hasattr(last_message, "content") else str(last_message)
# Extract JSON (strip markdown code block if present)
raw = re.sub(r"^```(?:json)?\s*", "", content.strip()).rstrip("`")
try:
    parsed = AgentResponse.model_validate_json(raw)
except Exception:
    start = raw.find("{")
    if start != -1:
        depth, end = 0, start
        for i, c in enumerate(raw[start:], start):
            if c == "{": depth += 1
            elif c == "}": depth -= 1
            if depth == 0: end = i; break
        parsed = AgentResponse.model_validate_json(raw[start:end+1])
    else:
        raise
print("Structured output:", parsed)
print("Top 3 ICD-10 codes:", parsed.ICD_10_code)
# Out:
# Structured output: ICD_10_code=['S22.1', 'I06.9', 'R42']
# Top 3 ICD-10 codes: ['S22.1', 'I06.9', 'R42']
